# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_ollama.llms import OllamaLLM

template = """Question: {question}

Answer: Let's think step by step."""

prompt = ChatPromptTemplate.from_template(template)

model = OllamaLLM(model="llama3.1")

chain = prompt | model

chain.invoke({"question": "What is LangChain?"})
# Out:
# 'To answer the question, "What is LangChain?", let\'s break it down step by step.\n\n**Step 1: Understanding the Context**\nLangChain seems to be related to programming or software development, given its name sounds technical and computational. It might involve languages, chains of commands, or perhaps artificial intelligence (AI) in some way.\n\n**Step 2: Possible Definitions**\nGiven its tech-oriented sound, LangChain could relate to:\n- A programming framework that enables the creation of complex logic flows.\n- An AI toolset for building conversational interfaces or chatbots.\n- A technology platform for automating tasks through a series of actions (chains).\n\n**Step 3: Researching Further**\nTo get more specific information about LangChain, one might need to visit its official website, GitHub page if it exists, or tech forums where developers and users discuss the latest tools and technologies. Search engines can also be used with keywords like "LangChain" in conjunction with terms that match our hypotheses.\n\n**Step 4: Analyzing Results**\nUpon finding relevant information about LangChain (which we\'re assuming could be anything from a platform for creating automations to an AI toolset), one would need to analyze what it does, its features, and how it compares or contrasts with other tools or technologies in the same domain.\n\n**Conclusion**\nGiven this step-by-step process, without direct access to more specific information about LangChain at this moment, we can\'t definitively state what it is. However, based on our initial deductions and a hypothetical process of exploration, it could be anything from an innovative tool for developers to a cutting-edge AI platform. Further research would clarify its true nature and capabilities.'

# %%
import base64
from io import BytesIO

from IPython.display import HTML, display
from PIL import Image


def convert_to_base64(pil_image):
    """
    Convert PIL images to Base64 encoded strings

    :param pil_image: PIL image
    :return: Re-sized Base64 string
    """

    buffered = BytesIO()
    pil_image.save(buffered, format="PNG")  # You can change the format if needed
    img_str = base64.b64encode(buffered.getvalue()).decode("utf-8")
    return img_str


def plt_img_base64(img_base64):
    """
    Display base64 encoded string as image

    :param img_base64:  Base64 string
    """
    # Create an HTML img tag with the base64 string as the source
    image_html = f'<img src="data:image/jpeg;base64,{img_base64}" />'
    # Display the image by rendering the HTML
    display(HTML(image_html))


file_path = "test.png"
pil_image = Image.open(file_path)
image_b64 = convert_to_base64(pil_image)
plt_img_base64(image_b64)
# Out:
# <img src="data:image/jpeg;base64,..." />

# %%
llm = OllamaLLM(model="llava")

llm_with_image_context = llm.bind(images=[image_b64])
llm_with_image_context.invoke("What do you see?")
# Out:
# " I don't have the ability to see or perceive visual information like a camera or human eye would. Is there something specific you would like me to describe or answer based on textual input? "
